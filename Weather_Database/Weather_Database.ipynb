# %%
from citipy import citipy
import numpy as np
import pandas as pd

# %%
# Import the requests library.
import requests

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=53a982d08f9754613a4653cb69cc1a81

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"] 
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0        
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Country": city_country,
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pirovskoye
# Processing Record 2 of Set 1 | abomsa
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | kaitangata
# Processing Record 10 of Set 1 | morehead
# Processing Record 11 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | thompson
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | viedma
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | alofi
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | ulladulla
# Processing Record 20 of Set 1 | bad mergentheim
# Processing Record 21 of Set 1 | poum
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | pemangkat
# Processing Record 24 of Set 1 | mecca
# Processing Record 25 of Set 1 | westport
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | upernavik
# Processing Record 29 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 1 | atar
# Processing Record 31 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | luderitz
# Processing Record 34 of Set 1 | karratha
# Processing Record 35 of Set 1 | sfantu gheorghe
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | butaritari
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | mataura
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | ostrovnoy
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | mackay
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | tiksi
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | cidreira
# Processing Record 48 of Set 1 | srednekolymsk
# Processing Record 49 of Set 1 | sekoma
# Processing Record 50 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 3 of Set 2 | puro
# Processing Record 4 of Set 2 | beni mazar
# Processing Record 5 of Set 2 | presidencia roque saenz pena
# Processing Record 6 of Set 2 | hilo
# Processing Record 7 of Set 2 | saldanha
# Processing Record 8 of Set 2 | matola
# Processing Record 9 of Set 2 | waingapu
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | gardan diwal
# City not found. Skipping...
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | quelimane
# Processing Record 15 of Set 2 | tres arroyos
# Processing Record 16 of Set 2 | airai
# Processing Record 17 of Set 2 | basqal
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | barntrup
# Processing Record 20 of Set 2 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 21 of Set 2 | busselton
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | tuktoyaktuk
# Processing Record 24 of Set 2 | ancud
# Processing Record 25 of Set 2 | dingle
# Processing Record 26 of Set 2 | nova olimpia
# Processing Record 27 of Set 2 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 29 of Set 2 | magadan
# Processing Record 30 of Set 2 | svetlogorsk
# Processing Record 31 of Set 2 | hambantota
# Processing Record 32 of Set 2 | liku
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | barrow
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | gol
# Processing Record 37 of Set 2 | cabo san lucas
# Processing Record 38 of Set 2 | bayburt
# Processing Record 39 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 2 | bambous virieux
# Processing Record 41 of Set 2 | mar del plata
# Processing Record 42 of Set 2 | burica
# City not found. Skipping...
# Processing Record 43 of Set 2 | georgetown
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | angoche
# Processing Record 46 of Set 2 | kayerkan
# Processing Record 47 of Set 2 | grand-santi
# Processing Record 48 of Set 2 | shenjiamen
# Processing Record 49 of Set 2 | los llanos de aridane
# Processing Record 50 of Set 2 | pandan
# Processing Record 1 of Set 3 | tura
# Processing Record 2 of Set 3 | fairbanks
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | uttarkashi
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | chokurdakh
# Processing Record 8 of Set 3 | aksu
# Processing Record 9 of Set 3 | norman wells
# Processing Record 10 of Set 3 | jasper
# Processing Record 11 of Set 3 | chebsara
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | leningradskiy
# Processing Record 14 of Set 3 | kruisfontein
# Processing Record 15 of Set 3 | pitimbu
# Processing Record 16 of Set 3 | griffith
# Processing Record 17 of Set 3 | yangambi
# Processing Record 18 of Set 3 | flinders
# Processing Record 19 of Set 3 | faanui
# Processing Record 20 of Set 3 | vostochnyy
# Processing Record 21 of Set 3 | wamba
# Processing Record 22 of Set 3 | buraydah
# Processing Record 23 of Set 3 | rypefjord
# Processing Record 24 of Set 3 | sosnovo-ozerskoye
# Processing Record 25 of Set 3 | mozarlandia
# Processing Record 26 of Set 3 | arshan
# Processing Record 27 of Set 3 | brokopondo
# Processing Record 28 of Set 3 | bethel
# Processing Record 29 of Set 3 | pangnirtung
# Processing Record 30 of Set 3 | seddon
# Processing Record 31 of Set 3 | indiaroba
# Processing Record 32 of Set 3 | muros
# Processing Record 33 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 3 | cockburn town
# Processing Record 35 of Set 3 | maldonado
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 38 of Set 3 | irbil
# Processing Record 39 of Set 3 | carmaux
# Processing Record 40 of Set 3 | gat
# Processing Record 41 of Set 3 | hobart
# Processing Record 42 of Set 3 | pergamino
# Processing Record 43 of Set 3 | novaya ladoga
# Processing Record 44 of Set 3 | drayton valley
# Processing Record 45 of Set 3 | pano aqil
# Processing Record 46 of Set 3 | pisco
# Processing Record 47 of Set 3 | calabozo
# Processing Record 48 of Set 3 | seoul
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | plainview
# Processing Record 1 of Set 4 | les cayes
# Processing Record 2 of Set 4 | launceston
# Processing Record 3 of Set 4 | phalaborwa
# Processing Record 4 of Set 4 | grand gaube
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | varhaug
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | kandrian
# Processing Record 9 of Set 4 | the valley
# Processing Record 10 of Set 4 | hermanus
# Processing Record 11 of Set 4 | kendari
# Processing Record 12 of Set 4 | saskylakh
# Processing Record 13 of Set 4 | chicama
# Processing Record 14 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 15 of Set 4 | itoman
# Processing Record 16 of Set 4 | bansko
# Processing Record 17 of Set 4 | ribeira grande
# Processing Record 18 of Set 4 | jamestown
# Processing Record 19 of Set 4 | acapulco
# Processing Record 20 of Set 4 | margate
# Processing Record 21 of Set 4 | castro
# Processing Record 22 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 4 | bambanglipuro
# Processing Record 24 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | port-cartier
# Processing Record 27 of Set 4 | omsukchan
# Processing Record 28 of Set 4 | nantucket
# Processing Record 29 of Set 4 | palmer
# Processing Record 30 of Set 4 | saint-augustin
# Processing Record 31 of Set 4 | el cobre
# Processing Record 32 of Set 4 | road town
# Processing Record 33 of Set 4 | arraial do cabo
# Processing Record 34 of Set 4 | aksarka
# Processing Record 35 of Set 4 | boralday
# Processing Record 36 of Set 4 | port elizabeth
# Processing Record 37 of Set 4 | opuwo
# Processing Record 38 of Set 4 | guozhen
# Processing Record 39 of Set 4 | nyurba
# Processing Record 40 of Set 4 | nome
# Processing Record 41 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 4 | sulangan
# Processing Record 43 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 44 of Set 4 | kodiak
# Processing Record 45 of Set 4 | puerto madero
# Processing Record 46 of Set 4 | marsh harbour
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | ahipara
# Processing Record 49 of Set 4 | mouzouras
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | kutum
# Processing Record 3 of Set 5 | soyo
# Processing Record 4 of Set 5 | kapuskasing
# Processing Record 5 of Set 5 | sale
# Processing Record 6 of Set 5 | ilulissat
# Processing Record 7 of Set 5 | hasaki
# Processing Record 8 of Set 5 | lasa
# Processing Record 9 of Set 5 | roanoke
# Processing Record 10 of Set 5 | new norfolk
# Processing Record 11 of Set 5 | santa maria
# Processing Record 12 of Set 5 | maloshuyka
# City not found. Skipping...
# Processing Record 13 of Set 5 | bagn
# Processing Record 14 of Set 5 | tuatapere
# Processing Record 15 of Set 5 | planaltina
# Processing Record 16 of Set 5 | preobrazheniye
# Processing Record 17 of Set 5 | hofn
# Processing Record 18 of Set 5 | yola
# Processing Record 19 of Set 5 | kiunga
# Processing Record 20 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 21 of Set 5 | manado
# Processing Record 22 of Set 5 | tilichiki
# Processing Record 23 of Set 5 | saint anthony
# Processing Record 24 of Set 5 | dmitriyevka
# Processing Record 25 of Set 5 | arlit
# Processing Record 26 of Set 5 | klaksvik
# Processing Record 27 of Set 5 | jalingo
# Processing Record 28 of Set 5 | sao joao da barra
# Processing Record 29 of Set 5 | sangueya
# Processing Record 30 of Set 5 | damghan
# Processing Record 31 of Set 5 | minusinsk
# Processing Record 32 of Set 5 | sindhnur
# Processing Record 33 of Set 5 | buin
# Processing Record 34 of Set 5 | fortuna
# Processing Record 35 of Set 5 | sao felix do xingu
# Processing Record 36 of Set 5 | yichun
# Processing Record 37 of Set 5 | guaruja
# Processing Record 38 of Set 5 | nieuw amsterdam
# Processing Record 39 of Set 5 | saint-joseph
# Processing Record 40 of Set 5 | sayyan
# Processing Record 41 of Set 5 | caravelas
# Processing Record 42 of Set 5 | broome
# Processing Record 43 of Set 5 | kavieng
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | terney
# Processing Record 46 of Set 5 | east london
# Processing Record 47 of Set 5 | barguzin
# Processing Record 48 of Set 5 | jalu
# Processing Record 49 of Set 5 | gladstone
# Processing Record 50 of Set 5 | kalmunai
# Processing Record 1 of Set 6 | antofagasta
# Processing Record 2 of Set 6 | celestun
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | awbari
# Processing Record 5 of Set 6 | praia da vitoria
# Processing Record 6 of Set 6 | coquimbo
# Processing Record 7 of Set 6 | sambava
# Processing Record 8 of Set 6 | salalah
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | southbridge
# Processing Record 11 of Set 6 | terre-de-bas
# Processing Record 12 of Set 6 | jiuquan
# Processing Record 13 of Set 6 | puerto narino
# Processing Record 14 of Set 6 | shablykino
# Processing Record 15 of Set 6 | kouroussa
# Processing Record 16 of Set 6 | ust-nera
# Processing Record 17 of Set 6 | cochrane
# Processing Record 18 of Set 6 | chara
# Processing Record 19 of Set 6 | malinovoye ozero
# Processing Record 20 of Set 6 | rongcheng
# Processing Record 21 of Set 6 | lagoa
# Processing Record 22 of Set 6 | coxim
# Processing Record 23 of Set 6 | omboue
# Processing Record 24 of Set 6 | keflavik
# Processing Record 25 of Set 6 | harper
# Processing Record 26 of Set 6 | bereda
# Processing Record 27 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 28 of Set 6 | deputatskiy
# Processing Record 29 of Set 6 | clyde river
# Processing Record 30 of Set 6 | raudeberg
# Processing Record 31 of Set 6 | port lincoln
# Processing Record 32 of Set 6 | portree
# Processing Record 33 of Set 6 | naze
# Processing Record 34 of Set 6 | port-gentil
# Processing Record 35 of Set 6 | balabac
# Processing Record 36 of Set 6 | lorengau
# Processing Record 37 of Set 6 | lata
# Processing Record 38 of Set 6 | kostomuksha
# Processing Record 39 of Set 6 | ketchikan
# Processing Record 40 of Set 6 | souillac
# Processing Record 41 of Set 6 | urumqi
# Processing Record 42 of Set 6 | catuday
# Processing Record 43 of Set 6 | adrar
# Processing Record 44 of Set 6 | mwense
# Processing Record 45 of Set 6 | san cristobal
# Processing Record 46 of Set 6 | leirvik
# Processing Record 47 of Set 6 | wildwood
# Processing Record 48 of Set 6 | sao filipe
# Processing Record 49 of Set 6 | altagracia de orituco
# Processing Record 50 of Set 6 | port hardy
# Processing Record 1 of Set 7 | sao jose da coroa grande
# Processing Record 2 of Set 7 | trnava
# Processing Record 3 of Set 7 | jatiroto
# Processing Record 4 of Set 7 | galle
# Processing Record 5 of Set 7 | hervey bay
# Processing Record 6 of Set 7 | carballo
# Processing Record 7 of Set 7 | la asuncion
# Processing Record 8 of Set 7 | kavaratti
# Processing Record 9 of Set 7 | balagansk
# Processing Record 10 of Set 7 | tutoia
# Processing Record 11 of Set 7 | yar-sale
# Processing Record 12 of Set 7 | wanning
# Processing Record 13 of Set 7 | brae
# Processing Record 14 of Set 7 | tutayev
# Processing Record 15 of Set 7 | valleyview
# Processing Record 16 of Set 7 | verin
# Processing Record 17 of Set 7 | boa vista
# Processing Record 18 of Set 7 | ponta do sol
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | berlevag
# Processing Record 21 of Set 7 | dunedin
# Processing Record 22 of Set 7 | talara
# Processing Record 23 of Set 7 | ronneby
# Processing Record 24 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 7 | vardo
# Processing Record 26 of Set 7 | sorata
# Processing Record 27 of Set 7 | najran
# Processing Record 28 of Set 7 | qibili
# City not found. Skipping...
# Processing Record 29 of Set 7 | plettenberg bay
# Processing Record 30 of Set 7 | goderich
# Processing Record 31 of Set 7 | russell
# Processing Record 32 of Set 7 | severobaykalsk
# Processing Record 33 of Set 7 | isangel
# Processing Record 34 of Set 7 | panzhihua
# Processing Record 35 of Set 7 | gotsu
# Processing Record 36 of Set 7 | fujin
# Processing Record 37 of Set 7 | cururupu
# Processing Record 38 of Set 7 | ipora
# Processing Record 39 of Set 7 | nguru
# Processing Record 40 of Set 7 | chunskiy
# Processing Record 41 of Set 7 | alice springs
# Processing Record 42 of Set 7 | san patricio
# Processing Record 43 of Set 7 | diamantino
# Processing Record 44 of Set 7 | mount gambier
# Processing Record 45 of Set 7 | yulara
# Processing Record 46 of Set 7 | devonport
# Processing Record 47 of Set 7 | san luis de la paz
# Processing Record 48 of Set 7 | tateyama
# Processing Record 49 of Set 7 | roald
# Processing Record 50 of Set 7 | vao
# Processing Record 1 of Set 8 | scarborough
# Processing Record 2 of Set 8 | kuryk
# Processing Record 3 of Set 8 | mareeba
# Processing Record 4 of Set 8 | tzucacab
# Processing Record 5 of Set 8 | ushibuka
# Processing Record 6 of Set 8 | mercedes
# Processing Record 7 of Set 8 | uniara
# Processing Record 8 of Set 8 | michigan city
# Processing Record 9 of Set 8 | bundoran
# Processing Record 10 of Set 8 | yerbogachen
# Processing Record 11 of Set 8 | nanortalik
# Processing Record 12 of Set 8 | katsuura
# Processing Record 13 of Set 8 | taoudenni
# Processing Record 14 of Set 8 | pasighat
# Processing Record 15 of Set 8 | sao pedro
# Processing Record 16 of Set 8 | olbia
# Processing Record 17 of Set 8 | victoria
# Processing Record 18 of Set 8 | acaponeta
# Processing Record 19 of Set 8 | lahij
# Processing Record 20 of Set 8 | lubartow
# Processing Record 21 of Set 8 | luangwa
# Processing Record 22 of Set 8 | lockport
# Processing Record 23 of Set 8 | fayetteville
# Processing Record 24 of Set 8 | saucillo
# Processing Record 25 of Set 8 | kinango
# Processing Record 26 of Set 8 | asau
# Processing Record 27 of Set 8 | talnakh
# Processing Record 28 of Set 8 | polunochnoye
# Processing Record 29 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 8 | rancharia
# Processing Record 31 of Set 8 | donceel
# Processing Record 32 of Set 8 | rocha
# Processing Record 33 of Set 8 | grindavik
# Processing Record 34 of Set 8 | votkinsk
# Processing Record 35 of Set 8 | hamilton
# Processing Record 36 of Set 8 | vestmannaeyjar
# Processing Record 37 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 38 of Set 8 | ingham
# Processing Record 39 of Set 8 | la libertad
# Processing Record 40 of Set 8 | kirakira
# Processing Record 41 of Set 8 | sisimiut
# Processing Record 42 of Set 8 | college
# Processing Record 43 of Set 8 | dzhankoy
# Processing Record 44 of Set 8 | atagay
# Processing Record 45 of Set 8 | maarianhamina
# Processing Record 46 of Set 8 | carutapera
# Processing Record 47 of Set 8 | beyneu
# Processing Record 48 of Set 8 | oussouye
# Processing Record 49 of Set 8 | chihuahua
# Processing Record 50 of Set 8 | grimmen
# Processing Record 1 of Set 9 | changji
# Processing Record 2 of Set 9 | tiarei
# Processing Record 3 of Set 9 | kamaishi
# Processing Record 4 of Set 9 | santa fe
# Processing Record 5 of Set 9 | gulshat
# City not found. Skipping...
# Processing Record 6 of Set 9 | codajas
# Processing Record 7 of Set 9 | mwingi
# Processing Record 8 of Set 9 | dudinka
# Processing Record 9 of Set 9 | lebu
# Processing Record 10 of Set 9 | banjar
# Processing Record 11 of Set 9 | saint-pierre
# Processing Record 12 of Set 9 | byron bay
# Processing Record 13 of Set 9 | male
# Processing Record 14 of Set 9 | subaytilah
# City not found. Skipping...
# Processing Record 15 of Set 9 | komsomolskiy
# Processing Record 16 of Set 9 | tambura
# Processing Record 17 of Set 9 | alyangula
# Processing Record 18 of Set 9 | teguise
# Processing Record 19 of Set 9 | nuuk
# Processing Record 20 of Set 9 | isilkul
# Processing Record 21 of Set 9 | torbay
# Processing Record 22 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 23 of Set 9 | birjand
# Processing Record 24 of Set 9 | cap malheureux
# Processing Record 25 of Set 9 | mount isa
# Processing Record 26 of Set 9 | gravdal
# Processing Record 27 of Set 9 | warrnambool
# Processing Record 28 of Set 9 | niesky
# Processing Record 29 of Set 9 | eyl
# Processing Record 30 of Set 9 | batemans bay
# Processing Record 31 of Set 9 | estelle
# Processing Record 32 of Set 9 | bozoum
# Processing Record 33 of Set 9 | tessalit
# Processing Record 34 of Set 9 | ryotsu
# Processing Record 35 of Set 9 | voznesenye
# Processing Record 36 of Set 9 | whitehorse
# Processing Record 37 of Set 9 | alindao
# Processing Record 38 of Set 9 | benemerito de las americas
# Processing Record 39 of Set 9 | sola
# Processing Record 40 of Set 9 | rangoon
# Processing Record 41 of Set 9 | padang
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | bulgan
# Processing Record 44 of Set 9 | port moresby
# Processing Record 45 of Set 9 | kenai
# Processing Record 46 of Set 9 | khormuj
# City not found. Skipping...
# Processing Record 47 of Set 9 | chufarovo
# Processing Record 48 of Set 9 | anloga
# Processing Record 49 of Set 9 | casablanca
# Processing Record 50 of Set 9 | khasan
# Processing Record 1 of Set 10 | gashua
# Processing Record 2 of Set 10 | tekeli
# Processing Record 3 of Set 10 | constitucion
# Processing Record 4 of Set 10 | general roca
# Processing Record 5 of Set 10 | port hedland
# Processing Record 6 of Set 10 | iranshahr
# Processing Record 7 of Set 10 | kaduqli
# Processing Record 8 of Set 10 | labuhan
# Processing Record 9 of Set 10 | ambilobe
# Processing Record 10 of Set 10 | marsaxlokk
# Processing Record 11 of Set 10 | andenes
# Processing Record 12 of Set 10 | polonnaruwa
# Processing Record 13 of Set 10 | batagay-alyta
# Processing Record 14 of Set 10 | riviere-du-loup
# Processing Record 15 of Set 10 | namibe
# Processing Record 16 of Set 10 | guarapari
# Processing Record 17 of Set 10 | cabedelo
# Processing Record 18 of Set 10 | weinan
# Processing Record 19 of Set 10 | tullamore
# Processing Record 20 of Set 10 | vila
# Processing Record 21 of Set 10 | nueva guinea
# Processing Record 22 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 10 | ondjiva
# Processing Record 24 of Set 10 | la palma
# Processing Record 25 of Set 10 | nyuksenitsa
# Processing Record 26 of Set 10 | mayo
# Processing Record 27 of Set 10 | troitsko-pechorsk
# Processing Record 28 of Set 10 | vysokogornyy
# Processing Record 29 of Set 10 | loni
# Processing Record 30 of Set 10 | sri aman
# Processing Record 31 of Set 10 | axim
# Processing Record 32 of Set 10 | zhengjiatun
# Processing Record 33 of Set 10 | jieshi
# Processing Record 34 of Set 10 | say
# Processing Record 35 of Set 10 | jaru
# Processing Record 36 of Set 10 | oriximina
# Processing Record 37 of Set 10 | mazagao
# Processing Record 38 of Set 10 | zabid
# Processing Record 39 of Set 10 | yelets
# Processing Record 40 of Set 10 | nizhniy kuranakh
# Processing Record 41 of Set 10 | marovoay
# Processing Record 42 of Set 10 | kuopio
# Processing Record 43 of Set 10 | lubango
# Processing Record 44 of Set 10 | concepcion del uruguay
# Processing Record 45 of Set 10 | cleburne
# Processing Record 46 of Set 10 | poiana marului
# Processing Record 47 of Set 10 | porto novo
# Processing Record 48 of Set 10 | awjilah
# Processing Record 49 of Set 10 | longyearbyen
# Processing Record 50 of Set 10 | luganville
# Processing Record 1 of Set 11 | lock haven
# Processing Record 2 of Set 11 | hami
# Processing Record 3 of Set 11 | aden
# Processing Record 4 of Set 11 | roxana
# Processing Record 5 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 11 | amga
# Processing Record 7 of Set 11 | santarem
# Processing Record 8 of Set 11 | kuminskiy
# Processing Record 9 of Set 11 | khaniotis
# Processing Record 10 of Set 11 | gorin
# Processing Record 11 of Set 11 | el sauzal
# Processing Record 12 of Set 11 | saint-francois
# Processing Record 13 of Set 11 | dali
# Processing Record 14 of Set 11 | deqing
# Processing Record 15 of Set 11 | praya
# Processing Record 16 of Set 11 | urengoy
# Processing Record 17 of Set 11 | querfurt
# Processing Record 18 of Set 11 | hukuntsi
# Processing Record 19 of Set 11 | araouane
# Processing Record 20 of Set 11 | san quintin
# Processing Record 21 of Set 11 | jiazi
# Processing Record 22 of Set 11 | gayny
# Processing Record 23 of Set 11 | yakeshi
# Processing Record 24 of Set 11 | susangerd
# Processing Record 25 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 11 | lodwar
# Processing Record 27 of Set 11 | antalaha
# Processing Record 28 of Set 11 | aquiraz
# Processing Record 29 of Set 11 | salekhard
# Processing Record 30 of Set 11 | korolevo
# Processing Record 31 of Set 11 | akyab
# Processing Record 32 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 33 of Set 11 | mehamn
# Processing Record 34 of Set 11 | richards bay
# Processing Record 35 of Set 11 | butte
# Processing Record 36 of Set 11 | conde
# Processing Record 37 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 38 of Set 11 | sinjah
# City not found. Skipping...
# Processing Record 39 of Set 11 | athens
# Processing Record 40 of Set 11 | payakumbuh
# Processing Record 41 of Set 11 | sebinkarahisar
# Processing Record 42 of Set 11 | andarab
# City not found. Skipping...
# Processing Record 43 of Set 11 | mae chan
# Processing Record 44 of Set 11 | mana
# Processing Record 45 of Set 11 | luba
# Processing Record 46 of Set 11 | phayakkhaphum phisai
# Processing Record 47 of Set 11 | aquin
# Processing Record 48 of Set 11 | san gabriel casa blanca
# Processing Record 49 of Set 11 | sorland
# Processing Record 50 of Set 11 | alexandria
# Processing Record 1 of Set 12 | maniitsoq
# Processing Record 2 of Set 12 | simao
# Processing Record 3 of Set 12 | cloquet
# Processing Record 4 of Set 12 | izazi
# Processing Record 5 of Set 12 | kushima
# Processing Record 6 of Set 12 | volovo
# Processing Record 7 of Set 12 | blonduos
# City not found. Skipping...
# Processing Record 8 of Set 12 | zhigansk
# Processing Record 9 of Set 12 | abiramam
# Processing Record 10 of Set 12 | remetea
# Processing Record 11 of Set 12 | banda aceh
# Processing Record 12 of Set 12 | porbandar
# Processing Record 13 of Set 12 | corn island
# Processing Record 14 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 12 | olafsvik
# Processing Record 16 of Set 12 | birobidzhan
# Processing Record 17 of Set 12 | ransang
# Processing Record 18 of Set 12 | sinnamary
# Processing Record 19 of Set 12 | honningsvag
# Processing Record 20 of Set 12 | harbour breton
# Processing Record 21 of Set 12 | udachnyy
# Processing Record 22 of Set 12 | gravelbourg
# Processing Record 23 of Set 12 | bairiki
# Processing Record 24 of Set 12 | quepos
# Processing Record 25 of Set 12 | newport
# Processing Record 26 of Set 12 | monte alegre
# Processing Record 27 of Set 12 | turtas
# Processing Record 28 of Set 12 | turukhansk
# Processing Record 29 of Set 12 | gizo
# Processing Record 30 of Set 12 | nanchong
# Processing Record 31 of Set 12 | salgueiro
# Processing Record 32 of Set 12 | mumford
# Processing Record 33 of Set 12 | golden
# Processing Record 34 of Set 12 | steamboat springs
# Processing Record 35 of Set 12 | sidmouth
# Processing Record 36 of Set 12 | gaspe
# Processing Record 37 of Set 12 | synya
# Processing Record 38 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 39 of Set 12 | kilindoni
# Processing Record 40 of Set 12 | makat
# Processing Record 41 of Set 12 | olinda
# Processing Record 42 of Set 12 | ayr
# Processing Record 43 of Set 12 | arkhangelskoye
# Processing Record 44 of Set 12 | ambunti
# Processing Record 45 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 46 of Set 12 | hailey
# Processing Record 47 of Set 12 | port blair
# Processing Record 48 of Set 12 | codrington
# Processing Record 49 of Set 12 | lakatoro
# Processing Record 50 of Set 12 | evensk
# Processing Record 1 of Set 13 | sydney
# Processing Record 2 of Set 13 | portland
# Processing Record 3 of Set 13 | belaya gora
# Processing Record 4 of Set 13 | rincon
# Processing Record 5 of Set 13 | harnosand
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 561

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Pirovskoye      RU  57.63   92.27     47.32        92          47
# 1       Abomsa      ET   9.98   39.98     71.38        64          74
# 2  Yellowknife      CA  62.46 -114.35     37.40        37          20
# 3        Vaini      TO -21.20 -175.20     75.20        78          40
# 4    Hithadhoo      MV  -0.60   73.08     81.18        72          91
# 5       Albany      US  42.60  -73.97     60.01        54          90
# 6   Nikolskoye      RU  59.70   30.79     48.99        87          99
# 7   Kaitangata      NZ -46.28  169.85     50.16        64          62
# 8     Morehead      US  37.27  -87.18     80.60        60           1
# 9      Ushuaia      AR -54.80  -68.30     37.40        69          40
#
#    Wind Speed Current Description
# 0        8.25    scattered clouds
# 1        5.32          light rain
# 2        8.05          few clouds
# 3       13.87    scattered clouds
# 4        7.38     overcast clouds
# 5        4.70               smoke
# 6        2.17                 fog
# 7       23.98       broken clouds
# 8        4.70           clear sky
# 9       18.34    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
